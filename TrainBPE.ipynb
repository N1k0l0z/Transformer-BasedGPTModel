# %%
from BPETokenizer import BPETOKENIZER
tokenizer = BPETOKENIZER('C:\\Users\\NiKordzakhia\\Desktop\\Tokenization\\vefxistyaosani.txt', 15000)
tokenizer.train()
# Out:
# Merging (225, 131) into a new token 256
# Merging (256, 144) into a new token 257
# Merging (32, 256) into a new token 258
# Merging (257, 256) into a new token 259
# Merging (256, 152) into a new token 260
# Merging (256, 148) into a new token 261
# Merging (261, 256) into a new token 262
# Merging (260, 256) into a new token 263
# Merging (257, 258) into a new token 264
# Merging (256, 157) into a new token 265
# Merging (256, 149) into a new token 266
# Merging (256, 147) into a new token 267
# Merging (256, 155) into a new token 268
# Merging (44, 258) into a new token 269
# Merging (256, 161) into a new token 270
# Merging (256, 160) into a new token 271
# Merging (259, 160) into a new token 272
# Merging (263, 161) into a new token 273
# Merging (256, 156) into a new token 274
# Merging (256, 154) into a new token 275
# Merging (260, 258) into a new token 276
# Merging (256, 151) into a new token 277
# Merging (256, 163) into a new token 278
# ...

# %%
# !pip install dill
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import dill as pickle

# %%
with open('C:\\Users\\NiKordzakhia\\Desktop\\Tokenization\\tokenizer', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
with open('C:\\Users\\NiKordzakhia\\Desktop\\Tokenization\\tokenizer', 'rb') as f:
    tokenizer = pickle.load(f)
