# %%
# !pip install dill
import dill as pickle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dill in c:\programdata\anaconda3\lib\site-packages (0.3.4)

# %%
from BPETokenizer import BPETOKENIZER
tokenizer = BPETOKENIZER('C:\\Users\\NiKordzakhia\\Desktop\\Transformer-BasedGPTModel\\vefxistyaosani.txt', 1000)
tokenizer.train()
# Out:
# Merging (12, 1) into a new token 49
# Merging (4, 1) into a new token 50
# Merging (12, 28) into a new token 51
# Merging (20, 29) into a new token 52
# Merging (20, 1) into a new token 53
# Merging (12, 24) into a new token 54
# Merging (15, 49) into a new token 55
# Merging (12, 15) into a new token 56
# Merging (12, 23) into a new token 57
# Merging (17, 16) into a new token 58
# Merging (1, 23) into a new token 59
# Merging (20, 19) into a new token 60
# Merging (29, 12) into a new token 61
# Merging (16, 13) into a new token 62
# Merging (4, 0) into a new token 63
# Merging (12, 17) into a new token 64
# Merging (16, 29) into a new token 65
# Merging (6, 0) into a new token 66
# Merging (15, 12) into a new token 67
# Merging (16, 24) into a new token 68
# Merging (29, 49) into a new token 69
# Merging (23, 25) into a new token 70
# Merging (16, 1) into a new token 71
# Merging (17, 20) into a new token 72
# Merging (31, 22) into a new token 73
# Merging (12, 22) into a new token 74
# Merging (16, 22) into a new token 75
# Merging (8, 0) into a new token 76
# Merging (29, 1) into a new token 77
# Merging (16, 23) into a new token 78
# Merging (66, 0) into a new token 79
# Merging (24, 12) into a new token 80
# Merging (16, 28) into a new token 81
# Merging (23, 12) into a new token 82
# Merging (19, 49) into a new token 83
# Merging (54, 1) into a new token 84
# Merging (63, 55) into a new token 85
# Merging (20, 50) into a new token 86
# Merging (20, 28) into a new token 87
# Merging (25, 13) into a new token 88
# Merging (38, 49) into a new token 89
# Merging (12, 50) into a new token 90
# Merging (56, 1) into a new token 91
# Merging (20, 22) into a new token 92
# Merging (52, 49) into a new token 93
# Merging (14, 12) into a new token 94
# Merging (24, 53) into a new token 95
# Merging (36, 16) into a new token 96
# Merging (52, 1) into a new token 97
# Merging (23, 20) into a new token 98
# Merging (51, 1) into a new token 99
# Merging (52, 12) into a new token 100
# Merging (15, 65) into a new token 101
# Merging (28, 49) into a new token 102
# Merging (28, 12) into a new token 103
# Merging (23, 16) into a new token 104
# Merging (37, 78) into a new token 105
# Merging (59, 25) into a new token 106
# Merging (17, 51) into a new token 107
# Merging (20, 24) into a new token 108
# Merging (7, 1) into a new token 109
# Merging (17, 60) into a new token 110
# Merging (17, 12) into a new token 111
# Merging (20, 15) into a new token 112
# Merging (79, 47) into a new token 113
# Merging (20, 12) into a new token 114
# Merging (109, 47) into a new token 115
# Merging (81, 19) into a new token 116
# Merging (28, 25) into a new token 117
# Merging (33, 23) into a new token 118
# Merging (36, 68) into a new token 119
# Merging (29, 50) into a new token 120
# Merging (31, 28) into a new token 121
# Merging (29, 20) into a new token 122
# Merging (42, 22) into a new token 123
# Merging (35, 25) into a new token 124
# Merging (58, 24) into a new token 125
# Merging (23, 52) into a new token 126
# Merging (12, 29) into a new token 127
# Merging (14, 84) into a new token 128
# Merging (19, 33) into a new token 129
# Merging (17, 22) into a new token 130
# Merging (58, 22) into a new token 131
# Merging (25, 24) into a new token 132
# Merging (19, 31) into a new token 133
# Merging (16, 19) into a new token 134
# Merging (14, 73) into a new token 135
# Merging (16, 50) into a new token 136
# Merging (19, 17) into a new token 137
# Merging (25, 28) into a new token 138
# Merging (40, 35) into a new token 139
# Merging (60, 1) into a new token 140
# Merging (0, 0) into a new token 141
# Merging (23, 71) into a new token 142
# Merging (60, 12) into a new token 143
# Merging (20, 14) into a new token 144
# Merging (25, 50) into a new token 145
# Merging (14, 57) into a new token 146
# Merging (17, 49) into a new token 147
# Merging (23, 84) into a new token 148
# Merging (23, 51) into a new token 149
# Merging (16, 30) into a new token 150
# Merging (28, 39) into a new token 151
# Merging (23, 54) into a new token 152
# Merging (80, 42) into a new token 153
# Merging (16, 15) into a new token 154
# Merging (24, 65) into a new token 155
# Merging (15, 92) into a new token 156
# Merging (42, 75) into a new token 157
# Merging (21, 12) into a new token 158
# Merging (17, 28) into a new token 159
# Merging (67, 50) into a new token 160
# Merging (12, 42) into a new token 161
# Merging (19, 12) into a new token 162
# Merging (31, 24) into a new token 163
# Merging (58, 28) into a new token 164
# Merging (19, 54) into a new token 165
# Merging (19, 1) into a new token 166
# Merging (25, 1) into a new token 167
# Merging (25, 23) into a new token 168
# Merging (61, 50) into a new token 169
# Merging (31, 13) into a new token 170
# Merging (19, 64) into a new token 171
# Merging (12, 30) into a new token 172
# Merging (25, 15) into a new token 173
# Merging (60, 49) into a new token 174
# Merging (14, 51) into a new token 175
# Merging (17, 52) into a new token 176
# Merging (15, 57) into a new token 177
# Merging (59, 20) into a new token 178
# Merging (72, 24) into a new token 179
# Merging (30, 35) into a new token 180
# Merging (26, 87) into a new token 181
# Merging (15, 64) into a new token 182
# Merging (20, 38) into a new token 183
# Merging (24, 20) into a new token 184
# Merging (24, 49) into a new token 185
# Merging (23, 18) into a new token 186
# Merging (12, 40) into a new token 187
# Merging (14, 64) into a new token 188
# Merging (101, 1) into a new token 189
# Merging (12, 33) into a new token 190
# Merging (58, 1) into a new token 191
# Merging (110, 49) into a new token 192
# Merging (44, 21) into a new token 193
# Merging (51, 20) into a new token 194
# Merging (62, 20) into a new token 195
# Merging (41, 87) into a new token 196
# Merging (12, 34) into a new token 197
# Merging (158, 38) into a new token 198
# Merging (25, 38) into a new token 199
# Merging (38, 28) into a new token 200
# Merging (76, 55) into a new token 201
# Merging (14, 54) into a new token 202
# Merging (42, 51) into a new token 203
# Merging (7, 0) into a new token 204
# Merging (2, 0) into a new token 205
# Merging (24, 31) into a new token 206
# Merging (23, 49) into a new token 207
# Merging (42, 17) into a new token 208
# Merging (105, 53) into a new token 209
# Merging (62, 52) into a new token 210
# Merging (16, 38) into a new token 211
# Merging (101, 50) into a new token 212
# Merging (51, 49) into a new token 213
# Merging (12, 14) into a new token 214
# Merging (57, 13) into a new token 215
# Merging (48, 79) into a new token 216
# Merging (28, 73) into a new token 217
# Merging (34, 23) into a new token 218
# Merging (133, 1) into a new token 219
# Merging (78, 22) into a new token 220
# Merging (31, 19) into a new token 221
# Merging (82, 19) into a new token 222
# Merging (40, 57) into a new token 223
# Merging (200, 220) into a new token 224
# Merging (17, 54) into a new token 225
# Merging (82, 14) into a new token 226
# Merging (65, 1) into a new token 227
# Merging (64, 165) into a new token 228
# Merging (228, 156) into a new token 229
# Merging (104, 32) into a new token 230
# Merging (12, 19) into a new token 231
# Merging (12, 61) into a new token 232
# Merging (144, 53) into a new token 233
# Merging (16, 14) into a new token 234
# Merging (29, 57) into a new token 235
# Merging (38, 42) into a new token 236
# Merging (141, 47) into a new token 237
# Merging (74, 53) into a new token 238
# Merging (21, 22) into a new token 239
# Merging (14, 20) into a new token 240
# Merging (21, 130) into a new token 241
# Merging (110, 1) into a new token 242
# Merging (82, 77) into a new token 243
# Merging (15, 20) into a new token 244
# Merging (59, 16) into a new token 245
# Merging (2, 48) into a new token 246
# Merging (151, 54) into a new token 247
# Merging (59, 52) into a new token 248
# Merging (32, 28) into a new token 249
# Merging (137, 97) into a new token 250
# Merging (129, 125) into a new token 251
# Merging (60, 42) into a new token 252
# Merging (18, 16) into a new token 253
# Merging (21, 17) into a new token 254
# Merging (16, 17) into a new token 255
# Merging (15, 51) into a new token 256
# Merging (15, 112) into a new token 257
# Merging (218, 116) into a new token 258
# Merging (29, 42) into a new token 259
# Merging (41, 159) into a new token 260
# Merging (37, 125) into a new token 261
# Merging (52, 50) into a new token 262
# Merging (72, 28) into a new token 263
# Merging (58, 13) into a new token 264
# Merging (80, 50) into a new token 265
# Merging (53, 23) into a new token 266
# Merging (24, 88) into a new token 267
# Merging (15, 34) into a new token 268
# Merging (260, 150) into a new token 269
# Merging (57, 12) into a new token 270
# Merging (25, 29) into a new token 271
# Merging (137, 74) into a new token 272
# Merging (28, 91) into a new token 273
# Merging (21, 51) into a new token 274
# Merging (24, 62) into a new token 275
# Merging (66, 55) into a new token 276
# Merging (164, 1) into a new token 277
# Merging (29, 40) into a new token 278
# Merging (68, 1) into a new token 279
# Merging (12, 13) into a new token 280
# Merging (54, 20) into a new token 281
# Merging (187, 1) into a new token 282
# Merging (28, 71) into a new token 283
# Merging (30, 194) into a new token 284
# Merging (28, 19) into a new token 285
# Merging (35, 28) into a new token 286
# Merging (75, 20) into a new token 287
# Merging (284, 75) into a new token 288
# Merging (29, 217) into a new token 289
# Merging (30, 87) into a new token 290
# Merging (15, 53) into a new token 291
# Merging (20, 80) into a new token 292
# Merging (24, 86) into a new token 293
# Merging (65, 49) into a new token 294
# Merging (241, 49) into a new token 295
# Merging (62, 73) into a new token 296
# Merging (30, 54) into a new token 297
# Merging (28, 16) into a new token 298
# Merging (23, 163) into a new token 299
# Merging (103, 89) into a new token 300
# Merging (12, 36) into a new token 301
# Merging (14, 18) into a new token 302
# Merging (221, 42) into a new token 303
# Merging (29, 73) into a new token 304
# Merging (119, 1) into a new token 305
# Merging (60, 50) into a new token 306
# Merging (35, 107) into a new token 307
# Merging (70, 13) into a new token 308
# Merging (33, 74) into a new token 309
# Merging (15, 97) into a new token 310
# Merging (88, 12) into a new token 311
# Merging (65, 71) into a new token 312
# Merging (33, 51) into a new token 313
# Merging (24, 75) into a new token 314
# Merging (149, 19) into a new token 315
# Merging (31, 42) into a new token 316
# Merging (29, 68) into a new token 317
# Merging (15, 25) into a new token 318
# Merging (96, 70) into a new token 319
# Merging (61, 42) into a new token 320
# Merging (36, 78) into a new token 321
# Merging (56, 50) into a new token 322
# Merging (155, 1) into a new token 323
# Merging (65, 50) into a new token 324
# Merging (72, 22) into a new token 325
# Merging (12, 115) into a new token 326
# Merging (23, 89) into a new token 327
# Merging (112, 132) into a new token 328
# Merging (31, 21) into a new token 329
# Merging (100, 63) into a new token 330
# Merging (122, 180) into a new token 331
# Merging (226, 102) into a new token 332
# Merging (9, 0) into a new token 333
# Merging (103, 115) into a new token 334
# Merging (249, 328) into a new token 335
# Merging (215, 64) into a new token 336
# Merging (15, 62) into a new token 337
# Merging (12, 18) into a new token 338
# Merging (2, 237) into a new token 339
# Merging (61, 76) into a new token 340
# Merging (22, 42) into a new token 341
# Merging (206, 1) into a new token 342
# Merging (59, 18) into a new token 343
# Merging (31, 33) into a new token 344
# Merging (38, 211) into a new token 345
# Merging (54, 53) into a new token 346
# Merging (80, 19) into a new token 347
# Merging (83, 23) into a new token 348
# Merging (345, 123) into a new token 349
# Merging (146, 25) into a new token 350
# Merging (53, 55) into a new token 351
# Merging (19, 90) into a new token 352
# Merging (61, 118) into a new token 353
# Merging (12, 43) into a new token 354
# Merging (36, 138) into a new token 355
# Merging (179, 1) into a new token 356
# Merging (20, 54) into a new token 357
# Merging (15, 14) into a new token 358
# Merging (32, 81) into a new token 359
# Merging (29, 38) into a new token 360
# Merging (15, 86) into a new token 361
# Merging (17, 74) into a new token 362
# Merging (62, 49) into a new token 363
# Merging (25, 22) into a new token 364
# Merging (17, 97) into a new token 365
# Merging (245, 32) into a new token 366
# Merging (82, 166) into a new token 367
# Merging (18, 34) into a new token 368
# Merging (35, 131) into a new token 369
# Merging (173, 1) into a new token 370
# Merging (52, 90) into a new token 371
# Merging (29, 59) into a new token 372
# Merging (12, 123) into a new token 373
# Merging (48, 113) into a new token 374
# Merging (36, 108) into a new token 375
# Merging (67, 14) into a new token 376
# Merging (17, 90) into a new token 377
# Merging (40, 12) into a new token 378
# Merging (40, 64) into a new token 379
# Merging (28, 57) into a new token 380
# Merging (75, 53) into a new token 381
# Merging (29, 25) into a new token 382
# Merging (20, 35) into a new token 383
# Merging (23, 40) into a new token 384
# Merging (61, 63) into a new token 385
# Merging (135, 53) into a new token 386
# Merging (61, 85) into a new token 387
# Merging (32, 183) into a new token 388
# Merging (13, 247) into a new token 389
# Merging (119, 53) into a new token 390
# Merging (26, 172) into a new token 391
# Merging (20, 17) into a new token 392
# Merging (114, 76) into a new token 393
# Merging (193, 56) into a new token 394
# Merging (20, 76) into a new token 395
# Merging (98, 24) into a new token 396
# Merging (14, 132) into a new token 397
# Merging (29, 56) into a new token 398
# Merging (20, 124) into a new token 399
# Merging (20, 51) into a new token 400
# Merging (36, 20) into a new token 401
# Merging (23, 68) into a new token 402
# Merging (175, 67) into a new token 403
# Merging (253, 55) into a new token 404
# Merging (100, 85) into a new token 405
# Merging (68, 60) into a new token 406
# Merging (124, 130) into a new token 407
# Merging (135, 69) into a new token 408
# Merging (43, 88) into a new token 409
# Merging (22, 91) into a new token 410
# Merging (103, 77) into a new token 411
# Merging (39, 34) into a new token 412
# Merging (22, 161) into a new token 413
# Merging (37, 24) into a new token 414
# Merging (100, 76) into a new token 415
# Merging (48, 66) into a new token 416
# Merging (155, 50) into a new token 417
# Merging (39, 22) into a new token 418
# Merging (38, 199) into a new token 419
# Merging (20, 23) into a new token 420
# Merging (56, 59) into a new token 421
# Merging (20, 85) into a new token 422
# Merging (16, 42) into a new token 423
# Merging (134, 1) into a new token 424
# Merging (68, 53) into a new token 425
# Merging (25, 67) into a new token 426
# Merging (369, 12) into a new token 427
# Merging (20, 63) into a new token 428
# Merging (20, 33) into a new token 429
# Merging (29, 52) into a new token 430
# Merging (30, 21) into a new token 431
# Merging (20, 42) into a new token 432
# Merging (21, 112) into a new token 433
# Merging (19, 50) into a new token 434
# Merging (58, 50) into a new token 435
# Merging (246, 141) into a new token 436
# Merging (42, 28) into a new token 437
# Merging (143, 63) into a new token 438
# Merging (72, 38) into a new token 439
# Merging (62, 28) into a new token 440
# Merging (430, 123) into a new token 441
# Merging (58, 95) into a new token 442
# Merging (67, 31) into a new token 443
# Merging (229, 1) into a new token 444
# Merging (73, 53) into a new token 445
# Merging (35, 23) into a new token 446
# Merging (38, 1) into a new token 447
# Merging (26, 25) into a new token 448
# Merging (198, 53) into a new token 449
# Merging (34, 49) into a new token 450
# Merging (20, 118) into a new token 451
# Merging (114, 85) into a new token 452
# Merging (104, 30) into a new token 453
# Merging (23, 75) into a new token 454
# Merging (20, 30) into a new token 455
# Merging (38, 267) into a new token 456
# Merging (171, 53) into a new token 457
# Merging (92, 53) into a new token 458
# Merging (24, 56) into a new token 459
# Merging (54, 31) into a new token 460
# Merging (62, 77) into a new token 461
# Merging (20, 32) into a new token 462
# Merging (29, 26) into a new token 463
# Merging (25, 14) into a new token 464
# Merging (68, 50) into a new token 465
# Merging (22, 301) into a new token 466
# Merging (57, 52) into a new token 467
# Merging (107, 15) into a new token 468
# Merging (30, 121) into a new token 469
# Merging (16, 59) into a new token 470
# Merging (22, 93) into a new token 471
# Merging (40, 56) into a new token 472
# Merging (303, 334) into a new token 473
# Merging (88, 49) into a new token 474
# Merging (188, 29) into a new token 475
# Merging (21, 263) into a new token 476
# Merging (170, 247) into a new token 477
# Merging (51, 53) into a new token 478
# Merging (72, 15) into a new token 479
# Merging (70, 14) into a new token 480
# Merging (13, 92) into a new token 481
# Merging (43, 81) into a new token 482
# Merging (58, 15) into a new token 483
# Merging (56, 76) into a new token 484
# Merging (70, 23) into a new token 485
# Merging (143, 76) into a new token 486
# Merging (105, 128) into a new token 487
# Merging (35, 207) into a new token 488
# Merging (134, 50) into a new token 489
# Merging (15, 168) into a new token 490
# Merging (23, 74) into a new token 491
# Merging (9, 48) into a new token 492
# Merging (24, 121) into a new token 493
# Merging (62, 12) into a new token 494
# Merging (124, 32) into a new token 495
# Merging (12, 21) into a new token 496
# Merging (28, 64) into a new token 497
# Merging (31, 32) into a new token 498
# Merging (56, 14) into a new token 499
# Merging (56, 106) into a new token 500
# Merging (28, 62) into a new token 501
# Merging (23, 140) into a new token 502
# Merging (36, 65) into a new token 503
# Merging (93, 23) into a new token 504
# Merging (72, 50) into a new token 505
# Merging (126, 53) into a new token 506
# Merging (466, 313) into a new token 507
# Merging (19, 107) into a new token 508
# Merging (42, 154) into a new token 509
# Merging (17, 99) into a new token 510
# Merging (469, 32) into a new token 511
# Merging (116, 152) into a new token 512
# Merging (274, 14) into a new token 513
# Merging (117, 142) into a new token 514
# Merging (28, 37) into a new token 515
# Merging (382, 32) into a new token 516
# Merging (205, 55) into a new token 517
# Merging (24, 51) into a new token 518
# Merging (34, 57) into a new token 519
# Merging (114, 63) into a new token 520
# Merging (13, 28) into a new token 521
# Merging (70, 72) into a new token 522
# Merging (51, 106) into a new token 523
# Merging (105, 69) into a new token 524
# Merging (58, 102) into a new token 525
# Merging (35, 51) into a new token 526
# Merging (31, 36) into a new token 527
# Merging (116, 53) into a new token 528
# Merging (20, 49) into a new token 529
# Merging (33, 132) into a new token 530
# Merging (36, 344) into a new token 531
# Merging (18, 28) into a new token 532
# Merging (108, 318) into a new token 533
# Merging (25, 77) into a new token 534
# Merging (56, 63) into a new token 535
# Merging (165, 49) into a new token 536
# Merging (13, 151) into a new token 537
# Merging (176, 115) into a new token 538
# Merging (419, 123) into a new token 539
# Merging (16, 145) into a new token 540
# Merging (32, 172) into a new token 541
# Merging (33, 58) into a new token 542
# Merging (51, 19) into a new token 543
# Merging (236, 68) into a new token 544
# Merging (139, 74) into a new token 545
# Merging (64, 77) into a new token 546
# Merging (12, 77) into a new token 547
# Merging (57, 84) into a new token 548
# Merging (17, 153) into a new token 549
# Merging (17, 57) into a new token 550
# Merging (20, 180) into a new token 551
# Merging (186, 71) into a new token 552
# Merging (175, 15) into a new token 553
# Merging (122, 254) into a new token 554
# Merging (22, 16) into a new token 555
# Merging (149, 166) into a new token 556
# Merging (57, 49) into a new token 557
# Merging (67, 29) into a new token 558
# Merging (51, 89) into a new token 559
# Merging (124, 131) into a new token 560
# Merging (40, 108) into a new token 561
# Merging (139, 22) into a new token 562
# Merging (20, 81) into a new token 563
# Merging (38, 31) into a new token 564
# Merging (14, 62) into a new token 565
# Merging (15, 210) into a new token 566
# Merging (55, 23) into a new token 567
# Merging (204, 47) into a new token 568
# Merging (171, 69) into a new token 569
# Merging (460, 1) into a new token 570
# Merging (302, 64) into a new token 571
# Merging (14, 413) into a new token 572
# Merging (554, 156) into a new token 573
# Merging (31, 23) into a new token 574
# Merging (36, 325) into a new token 575
# Merging (25, 101) into a new token 576
# Merging (30, 81) into a new token 577
# Merging (33, 238) into a new token 578
# Merging (133, 115) into a new token 579
# Merging (56, 85) into a new token 580
# Merging (39, 62) into a new token 581
# Merging (143, 85) into a new token 582
# Merging (299, 1) into a new token 583
# Merging (14, 151) into a new token 584
# Merging (152, 50) into a new token 585
# Merging (18, 51) into a new token 586
# Merging (15, 54) into a new token 587
# Merging (35, 225) into a new token 588
# Merging (15, 68) into a new token 589
# Merging (40, 292) into a new token 590
# Merging (43, 493) into a new token 591
# Merging (67, 20) into a new token 592
# Merging (24, 16) into a new token 593
# Merging (21, 56) into a new token 594
# Merging (96, 17) into a new token 595
# Merging (117, 1) into a new token 596
# Merging (19, 118) into a new token 597
# Merging (54, 50) into a new token 598
# Merging (29, 475) into a new token 599
# Merging (122, 539) into a new token 600
# Merging (61, 40) into a new token 601
# Merging (28, 112) into a new token 602
# Merging (391, 117) into a new token 603
# Merging (18, 168) into a new token 604
# Merging (36, 125) into a new token 605
# Merging (22, 168) into a new token 606
# Merging (117, 22) into a new token 607
# Merging (82, 375) into a new token 608
# Merging (35, 82) into a new token 609
# Merging (25, 189) into a new token 610
# Merging (25, 120) into a new token 611
# Merging (52, 59) into a new token 612
# Merging (38, 78) into a new token 613
# Merging (61, 170) into a new token 614
# Merging (16, 83) into a new token 615
# Merging (29, 409) into a new token 616
# Merging (341, 108) into a new token 617
# Merging (230, 71) into a new token 618
# Merging (239, 64) into a new token 619
# Merging (32, 51) into a new token 620
# Merging (28, 88) into a new token 621
# Merging (12, 76) into a new token 622
# Merging (69, 70) into a new token 623
# Merging (42, 54) into a new token 624
# Merging (157, 53) into a new token 625
# Merging (99, 94) into a new token 626
# Merging (44, 35) into a new token 627
# Merging (246, 0) into a new token 628
# Merging (15, 138) into a new token 629
# Merging (223, 25) into a new token 630
# Merging (270, 77) into a new token 631
# Merging (40, 144) into a new token 632
# Merging (150, 35) into a new token 633
# Merging (157, 384) into a new token 634
# Merging (634, 462) into a new token 635
# Merging (59, 231) into a new token 636
# Merging (57, 25) into a new token 637
# Merging (23, 73) into a new token 638
# Merging (203, 50) into a new token 639
# Merging (23, 56) into a new token 640
# Merging (16, 63) into a new token 641
# Merging (127, 283) into a new token 642
# Merging (127, 222) into a new token 643
# Merging (129, 442) into a new token 644
# Merging (129, 111) into a new token 645
# Merging (14, 72) into a new token 646
# Merging (23, 81) into a new token 647
# Merging (28, 90) into a new token 648
# Merging (33, 354) into a new token 649
# Merging (17, 77) into a new token 650
# Merging (42, 57) into a new token 651
# Merging (29, 30) into a new token 652
# Merging (336, 53) into a new token 653
# Merging (12, 85) into a new token 654
# Merging (259, 111) into a new token 655
# Merging (103, 19) into a new token 656
# Merging (261, 1) into a new token 657
# Merging (14, 16) into a new token 658
# Merging (8, 1) into a new token 659
# Merging (14, 225) into a new token 660
# Merging (512, 116) into a new token 661
# Merging (5, 23) into a new token 662
# Merging (14, 107) into a new token 663
# Merging (18, 464) into a new token 664
# Merging (94, 42) into a new token 665
# Merging (69, 55) into a new token 666
# Merging (181, 69) into a new token 667
# Merging (162, 128) into a new token 668
# Merging (104, 50) into a new token 669
# Merging (61, 33) into a new token 670
# Merging (61, 41) into a new token 671
# Merging (13, 154) into a new token 672
# Merging (12, 63) into a new token 673
# Merging (12, 166) into a new token 674
# Merging (82, 29) into a new token 675
# Merging (118, 24) into a new token 676
# Merging (17, 53) into a new token 677
# Merging (27, 57) into a new token 678
# Merging (64, 53) into a new token 679
# Merging (19, 42) into a new token 680
# Merging (44, 208) into a new token 681
# Merging (57, 89) into a new token 682
# Merging (78, 84) into a new token 683
# Merging (19, 242) into a new token 684
# Merging (64, 120) into a new token 685
# Merging (31, 236) into a new token 686
# Merging (42, 400) into a new token 687
# Merging (96, 72) into a new token 688
# Merging (179, 89) into a new token 689
# Merging (353, 71) into a new token 690
# Merging (61, 79) into a new token 691
# Merging (399, 1) into a new token 692
# Merging (107, 291) into a new token 693
# Merging (16, 32) into a new token 694
# Merging (15, 56) into a new token 695
# Merging (190, 49) into a new token 696
# Merging (15, 136) into a new token 697
# Merging (40, 81) into a new token 698
# Merging (218, 285) into a new token 699
# Merging (22, 49) into a new token 700
# Merging (259, 147) into a new token 701
# Merging (104, 59) into a new token 702
# Merging (95, 70) into a new token 703
# Merging (67, 13) into a new token 704
# Merging (17, 129) into a new token 705
# Merging (12, 69) into a new token 706
# Merging (133, 89) into a new token 707
# Merging (15, 262) into a new token 708
# Merging (368, 111) into a new token 709
# Merging (401, 128) into a new token 710
# Merging (20, 34) into a new token 711
# Merging (288, 1) into a new token 712
# Merging (51, 5) into a new token 713
# Merging (52, 5) into a new token 714
# Merging (154, 1) into a new token 715
# Merging (564, 15) into a new token 716
# Merging (29, 208) into a new token 717
# Merging (20, 90) into a new token 718
# Merging (121, 41) into a new token 719
# Merging (18, 161) into a new token 720
# Merging (13, 338) into a new token 721
# Merging (75, 69) into a new token 722
# Merging (309, 190) into a new token 723
# Merging (100, 113) into a new token 724
# Merging (118, 185) into a new token 725
# Merging (13, 607) into a new token 726
# Merging (224, 53) into a new token 727
# Merging (106, 23) into a new token 728
# Merging (12, 89) into a new token 729
# Merging (100, 202) into a new token 730
# Merging (17, 29) into a new token 731
# Merging (61, 113) into a new token 732
# Merging (12, 32) into a new token 733
# Merging (61, 66) into a new token 734
# Merging (57, 54) into a new token 735
# Merging (251, 1) into a new token 736
# Merging (289, 91) into a new token 737
# Merging (17, 93) into a new token 738
# Merging (111, 18) into a new token 739
# Merging (739, 87) into a new token 740
# Merging (64, 1) into a new token 741
# Merging (23, 97) into a new token 742
# Merging (13, 25) into a new token 743
# Merging (258, 148) into a new token 744
# Merging (21, 285) into a new token 745
# Merging (42, 199) into a new token 746
# Merging (106, 14) into a new token 747
# Merging (105, 250) into a new token 748
# Merging (412, 17) into a new token 749
# Merging (75, 83) into a new token 750
# Merging (14, 74) into a new token 751
# Merging (195, 63) into a new token 752
# Merging (62, 120) into a new token 753
# Merging (397, 62) into a new token 754
# Merging (51, 97) into a new token 755
# Merging (61, 307) into a new token 756
# Merging (198, 69) into a new token 757
# Merging (29, 51) into a new token 758
# Merging (94, 31) into a new token 759
# Merging (671, 719) into a new token 760
# Merging (268, 71) into a new token 761
# Merging (28, 56) into a new token 762
# Merging (396, 629) into a new token 763
# Merging (53, 70) into a new token 764
# Merging (24, 210) into a new token 765
# Merging (64, 50) into a new token 766
# Merging (61, 123) into a new token 767
# Merging (57, 310) into a new token 768
# Merging (29, 402) into a new token 769
# Merging (57, 91) into a new token 770
# Merging (48, 50) into a new token 771
# Merging (21, 252) into a new token 772
# Merging (25, 69) into a new token 773
# Merging (645, 115) into a new token 774
# Merging (22, 147) into a new token 775
# Merging (20, 113) into a new token 776
# Merging (36, 64) into a new token 777
# Merging (258, 69) into a new token 778
# Merging (49, 55) into a new token 779
# Merging (70, 50) into a new token 780
# Merging (751, 455) into a new token 781
# Merging (459, 87) into a new token 782
# Merging (20, 89) into a new token 783
# Merging (99, 67) into a new token 784
# Merging (561, 49) into a new token 785
# Merging (100, 128) into a new token 786
# Merging (16, 159) into a new token 787
# Merging (246, 237) into a new token 788
# Merging (379, 20) into a new token 789
# Merging (687, 73) into a new token 790
# Merging (20, 79) into a new token 791
# Merging (88, 92) into a new token 792
# Merging (331, 147) into a new token 793
# Merging (31, 38) into a new token 794
# Merging (83, 70) into a new token 795
# Merging (186, 16) into a new token 796
# Merging (139, 518) into a new token 797
# Merging (477, 326) into a new token 798
# Merging (13, 314) into a new token 799
# Merging (482, 1) into a new token 800
# Merging (333, 55) into a new token 801
# Merging (119, 128) into a new token 802
# Merging (403, 42) into a new token 803
# Merging (103, 29) into a new token 804
# Merging (40, 127) into a new token 805
# Merging (41, 17) into a new token 806
# Merging (256, 721) into a new token 807
# Merging (656, 128) into a new token 808
# Merging (100, 79) into a new token 809
# Merging (439, 86) into a new token 810
# Merging (14, 24) into a new token 811
# Merging (146, 20) into a new token 812
# Merging (18, 68) into a new token 813
# Merging (562, 73) into a new token 814
# Merging (107, 50) into a new token 815
# Merging (62, 29) into a new token 816
# Merging (67, 34) into a new token 817
# Merging (96, 14) into a new token 818
# Merging (25, 63) into a new token 819
# Merging (126, 128) into a new token 820
# Merging (51, 77) into a new token 821
# Merging (36, 81) into a new token 822
# Merging (25, 30) into a new token 823
# Merging (98, 591) into a new token 824
# Merging (195, 85) into a new token 825
# Merging (22, 197) into a new token 826
# Merging (181, 131) into a new token 827
# Merging (257, 53) into a new token 828
# Merging (440, 1) into a new token 829
# Merging (137, 52) into a new token 830
# Merging (161, 317) into a new token 831
# Merging (16, 85) into a new token 832
# Merging (111, 41) into a new token 833
# Merging (17, 31) into a new token 834
# Merging (335, 1) into a new token 835
# Merging (62, 90) into a new token 836
# Merging (204, 55) into a new token 837
# Merging (39, 314) into a new token 838
# Merging (75, 86) into a new token 839
# Merging (55, 70) into a new token 840
# Merging (122, 307) into a new token 841
# Merging (248, 53) into a new token 842
# Merging (760, 22) into a new token 843
# Merging (44, 660) into a new token 844
# Merging (25, 85) into a new token 845
# Merging (446, 548) into a new token 846
# Merging (96, 31) into a new token 847
# Merging (244, 54) into a new token 848
# Merging (14, 252) into a new token 849
# Merging (42, 207) into a new token 850
# Merging (20, 66) into a new token 851
# Merging (36, 28) into a new token 852
# Merging (61, 89) into a new token 853
# Merging (36, 226) into a new token 854
# Merging (5, 1) into a new token 855
# Merging (52, 42) into a new token 856
# Merging (77, 55) into a new token 857
# Merging (492, 0) into a new token 858
# Merging (158, 18) into a new token 859
# Merging (69, 96) into a new token 860
# Merging (117, 23) into a new token 861
# Merging (280, 43) into a new token 862
# Merging (20, 95) into a new token 863
# Merging (23, 38) into a new token 864
# Merging (51, 59) into a new token 865
# Merging (42, 172) into a new token 866
# Merging (23, 252) into a new token 867
# Merging (143, 79) into a new token 868
# Merging (40, 51) into a new token 869
# Merging (33, 111) into a new token 870
# Merging (51, 280) into a new token 871
# Merging (88, 232) into a new token 872
# Merging (88, 90) into a new token 873
# Merging (19, 110) into a new token 874
# Merging (94, 14) into a new token 875
# Merging (537, 68) into a new token 876
# Merging (14, 594) into a new token 877
# Merging (117, 29) into a new token 878
# Merging (437, 491) into a new token 879
# Merging (214, 283) into a new token 880
# Merging (341, 863) into a new token 881
# Merging (15, 154) into a new token 882
# Merging (24, 64) into a new token 883
# Merging (16, 73) into a new token 884
# Merging (60, 59) into a new token 885
# Merging (51, 178) into a new token 886
# Merging (551, 538) into a new token 887
# Merging (34, 81) into a new token 888
# Merging (19, 308) into a new token 889
# Merging (82, 50) into a new token 890
# Merging (116, 128) into a new token 891
# Merging (100, 66) into a new token 892
# Merging (67, 76) into a new token 893
# Merging (647, 142) into a new token 894
# Merging (389, 326) into a new token 895
# Merging (23, 269) into a new token 896
# Merging (172, 87) into a new token 897
# Merging (16, 76) into a new token 898
# Merging (21, 81) into a new token 899
# Merging (14, 108) into a new token 900
# Merging (59, 71) into a new token 901
# Merging (391, 20) into a new token 902
# Merging (34, 132) into a new token 903
# Merging (13, 51) into a new token 904
# Merging (60, 90) into a new token 905
# Merging (224, 83) into a new token 906
# Merging (533, 134) into a new token 907
# Merging (541, 152) into a new token 908
# Merging (431, 481) into a new token 909
# Merging (22, 25) into a new token 910
# Merging (101, 76) into a new token 911
# Merging (58, 34) into a new token 912
# Merging (278, 138) into a new token 913
# Merging (44, 315) into a new token 914
# Merging (59, 150) into a new token 915
# Merging (16, 106) into a new token 916
# Merging (92, 69) into a new token 917
# Merging (349, 53) into a new token 918
# Merging (231, 127) into a new token 919
# Merging (62, 426) into a new token 920
# Merging (380, 71) into a new token 921
# Merging (182, 20) into a new token 922
# Merging (26, 51) into a new token 923
# Merging (25, 55) into a new token 924
# Merging (103, 604) into a new token 925
# Merging (38, 157) into a new token 926
# Merging (114, 113) into a new token 927
# Merging (244, 49) into a new token 928
# Merging (61, 22) into a new token 929
# Merging (94, 16) into a new token 930
# Merging (32, 42) into a new token 931
# Merging (29, 121) into a new token 932
# Merging (21, 74) into a new token 933
# Merging (176, 128) into a new token 934
# Merging (44, 530) into a new token 935
# Merging (114, 66) into a new token 936
# Merging (43, 490) into a new token 937
# Merging (58, 29) into a new token 938
# Merging (24, 93) into a new token 939
# Merging (64, 22) into a new token 940
# Merging (26, 286) into a new token 941
# Merging (427, 158) into a new token 942
# Merging (58, 77) into a new token 943
# Merging (193, 252) into a new token 944
# Merging (188, 20) into a new token 945
# Merging (42, 211) into a new token 946
# Merging (427, 53) into a new token 947
# Merging (29, 106) into a new token 948
# Merging (105, 91) into a new token 949
# Merging (56, 113) into a new token 950
# Merging (320, 121) into a new token 951
# Merging (164, 89) into a new token 952
# Merging (117, 454) into a new token 953
# Merging (34, 187) into a new token 954
# Merging (13, 56) into a new token 955
# Merging (14, 23) into a new token 956
# Merging (347, 88) into a new token 957
# Merging (71, 55) into a new token 958
# Merging (29, 54) into a new token 959
# Merging (70, 35) into a new token 960
# Merging (196, 53) into a new token 961
# Merging (74, 86) into a new token 962
# Merging (292, 19) into a new token 963
# Merging (599, 53) into a new token 964
# Merging (5, 70) into a new token 965
# Merging (153, 147) into a new token 966
# Merging (343, 93) into a new token 967
# Merging (124, 1) into a new token 968
# Merging (62, 22) into a new token 969
# Merging (446, 93) into a new token 970
# Merging (25, 160) into a new token 971
# Merging (42, 99) into a new token 972
# Merging (31, 119) into a new token 973
# Merging (184, 63) into a new token 974
# Merging (39, 74) into a new token 975
# Merging (58, 40) into a new token 976
# Merging (126, 250) into a new token 977
# Merging (59, 51) into a new token 978
# Merging (12, 44) into a new token 979
# Merging (118, 80) into a new token 980
# Merging (49, 23) into a new token 981
# Merging (36, 88) into a new token 982
# Merging (140, 55) into a new token 983
# Merging (126, 83) into a new token 984
# Merging (34, 87) into a new token 985
# Merging (67, 63) into a new token 986
# Merging (67, 44) into a new token 987
# Merging (298, 43) into a new token 988
# Merging (287, 63) into a new token 989
# Merging (232, 76) into a new token 990
# Merging (149, 781) into a new token 991
# Merging (122, 203) into a new token 992
# Merging (521, 163) into a new token 993
# Merging (902, 27) into a new token 994
# Merging (181, 53) into a new token 995
# Merging (468, 69) into a new token 996
# Merging (177, 20) into a new token 997
# Merging (870, 13) into a new token 998
# Merging (633, 538) into a new token 999

# %%
with open('C:\\Users\\NiKordzakhia\\Desktop\\Transformer-BasedGPTModel\\tokenizer', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
with open('C:\\Users\\NiKordzakhia\\Desktop\\Transformer-BasedGPTModel\\tokenizer', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
with open('C:\\Users\\NiKordzakhia\\Desktop\\Transformer-BasedGPTModel\\vefxistyaosani.txt', 'r') as f:
    data = f.read()

# %%
encoded = tokenizer.encode(data[:1000])

# %%
for i in encoded:
    print(tokenizer.decode([i]))
# Out:
# ვე
# ფხ
# ის
# ტყ
# ა
# ოს
# ანი
#
#
# და
# სა
# წყ
# ის
# ი
#
#
#
# რომელ
# მან
# შე
# ქმნა
# სამ
# ყარ
# ო
# ძალ
# ითა
# მით
# ძლ
# იერ
# ითა,
#
# ზე
# გარდ
# მო
#
# არ
# ს
# ნი
# სულ
# ითა
# ყ
# ვ
# ნა
# ზ
# ეც
# ით
#  მო
# ნა
# ბ
# ერ
# ითა,
#
# ჩვენ
# ,
# კაც
# თა,
# მოგ
# ვ
# ცა
# ქვე
# ყ
# ან
# ა,
# გ
# ვა
# ქ
# ვს
# უ
# თვალ
# ავი
# ფერ
# ითა,
# და
# მისგან
# არს
# ყოვლ
# ი
# ხელმწიფ
# ე
# სახ
# ითა
# მის
#  მი
# ერ
# ითა.
#
#
# ჰ
# ე,
# ღმერთ
# ო
# ერთ
# ო,
# შენ
# შე
# ჰ
# ქმ
# ენ
# სახ
# ე
# ყოვლ
# ისა
# ტან
# ისა,
#
# შენ
# დამ
# იფ
# არ
# ე,
# ძლ
# ე
# ვა
# მე
# ც
# და
# თ
# რ
# გ
# უნ
# ვ
# ად მ
# ე
# სა
# ტან
# ისა,
#
# მო
# მე
# ც
#  მი
# ჯნურ
# თა
# სურ
# ვილ
# ი,
# სიკვ
# დიდ
# მ
# დ
# ე
# გა
# სა
# ტან
# ისა,
# და
# ც
# ოდ
# ვა
# თა
# შეს
# უბ
# უქ
# ება,
# მუნ
# თანა
# წ
# ასა
# ტან
# ისა.
#
#
# ვის
# ჰ
# შვენ
# ის
# ,
# -
# ლომ
# სა
# ,
# -
# ხ
# მარ
# ება
# შ
# უბ
# ისა,
# ფარ
# -
# ში
# მ
# შერ
# ისა,
#
# მეფ
# ისა
# მზ
# ის
# თ
# ამ
# არ
# ისა
# ღაწ
# ვ
# -
# ბად
# ახ
# შ
# -
# თ
# მა
# -
# გი
# შერ
# ისა,
#
# მა
# ს,
# არა
# ვიცი,
# შევ
# ჰკად
# რო
# შეს
# ხმა
# ხ
# ოტ
# ბ
# ისა
# შე
# -
# რ
# ისა,
# და
# მის
# თა მ
# ჭვრეტ
# ელთა
# ყ
# ან
# დ
# ისა მ
# ირ
# თ
# მა
# ხამ
# ს მ
# ართ
#  მი
# -
# შერ
# ისა.
#
#
# თ
# ამ
# არს
# ვა
# ქ
# ებ
# დ
# ეთ
#  მეფ
# ე
# სა,
# სისხლ
# ისა
# ცრემლ
# -
# და
# თხ
# ეულ
# ი,
#
# ვ
# თქვენი
# ქ
# ებ
# ანი
# ვის
# ნი
# მე,
# არ-
# ავ
# ად
# გამ
# ორ
# ჩ
# ეულ
# ი.
#
# მელ
# ნ
# ად
# ვი
# ხ
# მარ
# ე
# გი
# შრ
# ის
# ტ
# ბ
# ა და
# კალ
# მ
# ად მ
# ე
# ნა
# რ
# ხ
# ეულ
# ი,
# და
# ვინცა
# ის
# მინ
# ოს,
# და
# ეს
# ვა
# ს
# ლახ
# ვარ
# ი
# გულსა
# ხ
# ეულ
# ი.
#
#
# მი
# ბრძან
# ეს
#  მათ
# ად
# საქ
# ებ
# რად
# თქმ
# ა
# ლე
# ქ
# ს
# ებ
# ისა
# ტკბილ
# ისა,
#
# ქ
# ება
# წარ
# ბ
# თა
# და
# წამ
# წამ
# თა,
# თ
# მა
# თა
# და
# ბ
# აგ
# ე
# -
# კ
# ბილ
# ისა,
#
# ბროლ
# -
# ბად
# ახ
# შ
# ისა
# თ
# ლ
# ილ
# ისა,
# მ
# ით
#  მი
# ჯ
# რ
# ით
#  მი
# წყ
# ობილ
# ისა,
# და
# გა
# სტ
# ეხ
# ს
# ქვა
# საცა
# მა
# გარ
# სა
# გ
# რ
# დ
# ემლ
# ი
# ტყ
# ვი
# ისა
# ლ
# ბილ
# ის
